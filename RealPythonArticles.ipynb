# %%
```python

import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://realpython.com/"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

articles = soup.find_all("div", class_="card-body m-0 p-0 mt-2")

data= []

for article in articles:

    title = article.find("h2", class_="card-title h4 my-0 py-0").text.strip()
    date = article.find("span", class_="mr-2").text.strip()
    lnk = article.a["href"]
    link = "https://realpython.com" + lnk
    data.append({"Title":title, "Date":date, "Link":link})

df = pd.DataFrame(data)
df.to_csv("RealPythonArticles.csv", encoding="utf-8-sig")

```
# Out:
#                                                 Title          Date  \
# 0                  Using the Python subprocess Module  May 06, 2025
# 1                                      Sets in Python  May 05, 2025
# 2      Modern Web Automation With Python and Selenium  Apr 30, 2025
# 3   Thread Safety in Python: Locks and Other Techn...  Apr 29, 2025
# 4   Managing Python Projects With uv: An All-in-On...  Apr 28, 2025
# 5                    Getting Started With Python IDLE  Apr 23, 2025
# 6                          MySQL Databases and Python  Apr 22, 2025
# 7   How to Copy Objects in Python: Shallow vs Deep...  Apr 21, 2025
# 8   How to Exit Loops Early With the Python Break ...  Apr 16, 2025
# 9             Creating a Python Dice Roll Application  Apr 15, 2025
# 10                               Namespaces in Python  Apr 14, 2025
# 11   Using Python's .__dict__ to Work With Attributes  Apr 09, 2025
# 12  Checking for Membership Using Python's "in" an...  Apr 08, 2025
# ...
